# %% [markdown]
# # finding all 62 links on main page

# %%
import requests
import json
import re

# URL of the 62-cookie recipe page
url = "https://food52.com/story/26826-best-cookie-recipes"

response = requests.get(url)
html_content = response.text

external_urls= re.findall(r'"externalUrl":"(https://food52\.com/(?:recipes|blog)/\d{5}-[^"]+)"', html_content)

external_urls = list(set(external_urls))

keep_exceptions = {"25372","26755","14625", "25558"}

def first5digits(url):
  return url.split('/')[-1][:5]

filtered_urls = [
    url for url in external_urls
    if first5digits(url) in keep_exceptions or not (
        first5digits(url).startswith('1') or
        first5digits(url).startswith('2') or
        first5digits(url) == '34397'
    )
]


print("Found", len(filtered_urls), "external URLs:")
for link in filtered_urls:
    print(link)
# Out:
# Found 62 external URLs:
# https://food52.com/recipes/82256-chipotle-chocolate-crinkle-cookies
# https://food52.com/recipes/82219-chai-spice-snickerdoodle-recipe
# https://food52.com/recipes/83254-mm-cookies-recipe
# https://food52.com/recipes/85409-blueberry-pecan-oat-thumbprint-cookies
# https://food52.com/recipes/39582-spritz-butter-christmas-cookies
# https://food52.com/recipes/31624-parisian-macarons
# https://food52.com/recipes/82227-caramelized-white-chocolate-cookies-recipe
# https://food52.com/recipes/66073-dorie-greenspan-s-do-almost-anything-vanilla-cookie-dough
# https://food52.com/recipes/76919-salted-chocolate-buckwheat-cookie
# https://food52.com/recipes/80770-buttermilk-chocolate-chip-cookies
# https://food52.com/recipes/40302-homemade-thin-mint-inspired-cookies
# https://food52.com/recipes/86477-best-apple-pie-cookies-recipe
# https://food52.com/recipes/39132-ovenly-s-secretly-vegan-salted-chocolate-chip-cookies
# https://food52.com/recipes/82212-almond-biscotti-recipe
# https://food52.com/recipes/86604-kristens-genius-family-banana-bread-recipe
# https://food52.com/recipes/25372-pierre-herme-dorie-greenspan-s-world-peace-cookies
# https://food52.com/recipes/76006-soft-yogurt-cookies-with-raspberry-glaze
# https://food52.com/recipes/66071-olive-oil-sugar-cookies
# https://food52.com/recipes/81249-bien-cuit-shortbread
# https://food52.com/recipes/82223-danish-butter-cookie-with-currants-recipe
# https://food52.com/recipes/39308-italian-rainbow-cookies
# https://food52.com/recipes/85019-miso-peanut-butter-cookies-black-sesame-chocolate-recipe
# https://food52.com/recipes/76338-vietnamese-iced-coffee-cookies
# https://food52.com/recipes/86351-raspberry-amaretti-cookies-recipe
# https://food52.com/recipes/40259-homemade-samoa-inspired-cookies
# https://food52.com/recipes/25558-chocolate-chip-cookies
# https://food52.com/recipes/55184-oatmeal-raisin-cookies
# https://food52.com/blog/26755-dorie-greenspan-chocolate-chip-cookies
# https://food52.com/recipes/85345-matcha-mochi-cookies
# https://food52.com/recipes/83762-aunt-lollys-oatmeal-chocolate-chip-cookie-recipe
# https://food52.com/recipes/85072-3-ingredient-peanut-butter-cookies-recipe
# https://food52.com/recipes/82252-strawberry-white-chocolate-macadamia-nut-milk-chocolate-cookie-recipe
# https://food52.com/recipes/82215-salted-rosemary-shortbread
# https://food52.com/recipes/82667-spiced-pecan-sandies-recipe
# https://food52.com/recipes/78310-rose-levy-beranbaum-s-molasses-sugar-butter-cookies
# https://food52.com/recipes/39753-s-mores-cookies
# https://food52.com/recipes/86168-best-applesauce-chocolate-chip-cookies-recipe
# https://food52.com/recipes/84404-best-butter-cookies-recipe-with-fruit
# https://food52.com/recipes/78230-vegan-dark-chocolate-gingerbread-thumbprint-cookies
# https://food52.com/recipes/39059-holiday-crinkle-cookies
# https://food52.com/recipes/81563-pan-banging-chocolate-chip-cookies-recipe-adaptation
# https://food52.com/recipes/39596-vegan-sugar-cookies
# https://food52.com/recipes/82228-olive-oil-sugar-cookies-recipe-with-pistachios-lemon
# https://food52.com/recipes/69556-danielle-kartes-coconut-custard-macaroons
# https://food52.com/recipes/82323-peanut-butter-chocolate-chocolate-chip-cookies-recipe
# https://food52.com/recipes/78317-chocolate-sandwich-cookies
# https://food52.com/recipes/81372-chewy-chocolate-chip-cookies-with-rainbow-fennel-seeds
# https://food52.com/recipes/14625-cream-cheese-cookies
# https://food52.com/recipes/85471-best-chocolate-macaron-recipe
# https://food52.com/recipes/80855-banana-bread-chocolate-chunk-cookies
# https://food52.com/recipes/83072-kitchen-sink-cookies-recipe-gaby-dalkin
# https://food52.com/recipes/74355-peanut-butter-peppermint-chip-cookies
# https://food52.com/recipes/82236-red-velvet-cookies-recipe
# https://food52.com/recipes/39366-matcha-butter-cookies
# https://food52.com/recipes/35914-orange-pistachio-biscotti
# https://food52.com/recipes/82971-linzer-cookies-recipe
# https://food52.com/recipes/65919-soft-puffy-snickerdoodles
# https://food52.com/recipes/78106-sugar-cookie-bars
# https://food52.com/recipes/84523-best-gingerbread-cookies-recipe
# https://food52.com/recipes/67298-russian-tea-cakes
# https://food52.com/recipes/82253-sugar-cookies-with-vanilla-frosting
# https://food52.com/recipes/86504-my-family-recipe-mom-moms-potato-chip-cookie

# %% [markdown]
# # choosing one URL to inspect ingredients

# %%
import requests
from bs4 import BeautifulSoup

url = filtered_urls[0]
print(url)
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

li_tags = soup.find_all("li")
for li in li_tags:
    print(li.get_text(strip=True))

#there should only be 14 ingredients
# Out:
# https://food52.com/recipes/82256-chipotle-chocolate-crinkle-cookies
# Schoolhouse
# Dansk
# ShopNewBest SellersExclusively at Food52Featured MakersKitchenKitchen Utensils & ToolsKitchen Storage & OrganizationCountertop OrganizationFood StorageKitchen LinensCutting BoardsCoffee & Tea AccessoriesKnivesCookwareFrying Pans & SkilletsBaking & Roasting PansDutch Ovens & Stock PotsSauce & Saute PansCookware SetsTabletopDinnerwareGlasswareTable LinensFlatware & Serving UtensilsServewareOutdoor EntertainingHomeOrganization & StorageCleaning & LaundryBath Towels & AccessoriesVases & Decorative ObjectsClocks & LightingCandles & Candle HoldersPlantersShop All
# New
# Best Sellers
# Exclusively at Food52
# Featured Makers
# KitchenKitchen Utensils & ToolsKitchen Storage & OrganizationCountertop OrganizationFood StorageKitchen LinensCutting BoardsCoffee & Tea AccessoriesKnives
# Kitchen Utensils & Tools
# Kitchen Storage & Organization
# Countertop Organization
# Food Storage
# Kitchen Linens
# Cutting Boards
# Coffee & Tea Accessories
# Knives
# CookwareFrying Pans & SkilletsBaking & Roasting PansDutch Ovens & Stock PotsSauce & Saute PansCookware Sets
# Frying Pans & Skillets
# Baking & Roasting Pans
# Dutch Ovens & Stock Pots
# Sauce & Saute Pans
# Cookware Sets
# TabletopDinnerwareGlasswareTable LinensFlatware & Serving UtensilsServewareOutdoor Entertaining
# Dinnerware
# Glassware
# Table Linens
# Flatware & Serving Utensils
# Serveware
# Outdoor Entertaining
# HomeOrganization & StorageCleaning & LaundryBath Towels & AccessoriesVases & Decorative ObjectsClocks & LightingCandles & Candle HoldersPlanters
# Organization & Storage
# Cleaning & Laundry
# Bath Towels & Accessories
# Vases & Decorative Objects
# Clocks & Lighting
# Candles & Candle Holders
# Planters
# RecipesPopularQuick and Easy5 Ingredients or FewerCocktailsAppetizersIngredientsChickenSteakSalmonPastaPotatoRiceMeals & DishesBreakfastLunchDinnerSaladSweet TreatsLifestyleVegetarianVeganGluten-FreeAlcohol-Free DrinksTools & TechniquesOne PotSheet PanNo BakeGrill
# PopularQuick and Easy5 Ingredients or FewerCocktailsAppetizers
# Quick and Easy
# 5 Ingredients or Fewer
# Cocktails
# Appetizers
# IngredientsChickenSteakSalmonPastaPotatoRice
# Chicken
# Steak
# Salmon
# Pasta
# Potato
# Rice
# Meals & DishesBreakfastLunchDinnerSaladSweet Treats
# Breakfast
# Lunch
# Dinner
# Salad
# Sweet Treats
# LifestyleVegetarianVeganGluten-FreeAlcohol-Free Drinks
# Vegetarian
# Vegan
# Gluten-Free
# Alcohol-Free Drinks
# Tools & TechniquesOne PotSheet PanNo BakeGrill
# One Pot
# Sheet Pan
# No Bake
# Grill
# LifeTravelHosting & EntertainmentParentingPetsKitchen SinkCrafts & HobbiesCommunityView All
# Travel
# Hosting & Entertainment
# Parenting
# Pets
# Kitchen Sink
# Crafts & Hobbies
# Community
# FoodRecipesHow To & HacksMeal PlanningBakingTrending & SeasonalDrinksCommunityHotlineView All
# Recipes
# How To & Hacks
# Meal Planning
# Baking
# Trending & Seasonal
# Drinks
# Community
# Hotline
# HomeStyle & DesignCleaning & OrganizingOutdoorsRenovationHome ToursView All
# Style & Design
# Cleaning & Organizing
# Outdoors
# Renovation
# Home Tours
# Watch
# ShopAll ShopNewBest SellersExclusively at Food52Featured MakersKitchenKitchen Utensils & ToolsKitchen Storage & OrganizationCountertop OrganizationFood StorageKitchen LinensCutting BoardsCoffee & Tea AccessoriesKnivesCookwareFrying Pans & SkilletsBaking & Roasting PansDutch Ovens & Stock PotsSauce & Saute PansCookware SetsTabletopDinnerwareGlasswareTable LinensFlatware & Serving UtensilsServewareOutdoor EntertainingHomeOrganization & StorageCleaning & LaundryBath Towels & AccessoriesVases & Decorative ObjectsClocks & LightingCandles & Candle HoldersPlantersShop all Shop
# All Shop
# New
# Best Sellers
# Exclusively at Food52
# Featured Makers
# KitchenKitchen Utensils & ToolsKitchen Storage & OrganizationCountertop OrganizationFood StorageKitchen LinensCutting BoardsCoffee & Tea AccessoriesKnives
# Kitchen Utensils & Tools
# Kitchen Storage & Organization
# Countertop Organization
# Food Storage
# Kitchen Linens
# Cutting Boards
# Coffee & Tea Accessories
# Knives
# CookwareFrying Pans & SkilletsBaking & Roasting PansDutch Ovens & Stock PotsSauce & Saute PansCookware Sets
# Frying Pans & Skillets
# Baking & Roasting Pans
# Dutch Ovens & Stock Pots
# Sauce & Saute Pans
# Cookware Sets
# TabletopDinnerwareGlasswareTable LinensFlatware & Serving UtensilsServewareOutdoor Entertaining
# Dinnerware
# Glassware
# Table Linens
# Flatware & Serving Utensils
# Serveware
# Outdoor Entertaining
# HomeOrganization & StorageCleaning & LaundryBath Towels & AccessoriesVases & Decorative ObjectsClocks & LightingCandles & Candle HoldersPlanters
# Organization & Storage
# Cleaning & Laundry
# Bath Towels & Accessories
# Vases & Decorative Objects
# Clocks & Lighting
# Candles & Candle Holders
# Planters
# Shop all Shop
# RecipesAll RecipesPopularQuick and Easy5 Ingredients or FewerCocktailsAppetizersIngredientsChickenSteakSalmonPastaPotatoRiceMeals & DishesBreakfastLunchDinnerSaladSweet TreatsLifestyleVegetarianVeganGluten-FreeAlcohol-Free DrinksTools & TechniquesOne PotSheet PanNo BakeGrill
# All Recipes
# PopularQuick and Easy5 Ingredients or FewerCocktailsAppetizers
# Quick and Easy
# 5 Ingredients or Fewer
# Cocktails
# Appetizers
# IngredientsChickenSteakSalmonPastaPotatoRice
# Chicken
# Steak
# Salmon
# Pasta
# Potato
# Rice
# Meals & DishesBreakfastLunchDinnerSaladSweet Treats
# Breakfast
# Lunch
# Dinner
# Salad
# Sweet Treats
# LifestyleVegetarianVeganGluten-FreeAlcohol-Free Drinks
# Vegetarian
# Vegan
# Gluten-Free
# Alcohol-Free Drinks
# Tools & TechniquesOne PotSheet PanNo BakeGrill
# One Pot
# Sheet Pan
# No Bake
# Grill
# LifeAll LifeTravelHosting & EntertainmentParentingPetsKitchen SinkCrafts & HobbiesCommunityShop all Life
# All Life
# Travel
# Hosting & Entertainment
# Parenting
# Pets
# Kitchen Sink
# Crafts & Hobbies
# Community
# Shop all Life
# FoodAll FoodRecipesHow To & HacksMeal PlanningBakingTrending & SeasonalDrinksCommunityHotlineShop all Food
# All Food
# Recipes
# How To & Hacks
# Meal Planning
# Baking
# Trending & Seasonal
# Drinks
# Community
# Hotline
# Shop all Food
# HomeAll HomeStyle & DesignCleaning & OrganizingOutdoorsRenovationHome ToursShop all Home
# All Home
# Style & Design
# Cleaning & Organizing
# Outdoors
# Renovation
# Home Tours
# Shop all Home
# Watch
# Account
# 1/4cup(31g) all-purpose flour
# 1/4teaspoonbaking powder
# 1/4teaspoonsalt
# 2large eggs
# 2/3cup(133g) granulated sugar
# 1 1/4teaspoonpure Mexican vanilla extract
# 2tablespoonunsalted butter
# 5ounce(142g) extra-bittersweet chocolate, chopped
# 2ounce(57g) unsweetened chocolate, chopped
# 4ounce(113g) mini chocolate chips or bittersweet chocolate, finely chopped
# 1 1/2tablespoonchipotle chile paste (recipe below)
# 6medium chipotle chiles (for chipotle paste—see note) (1 ounce, or 28g)
# Granulated sugar
# Confectioner's sugar
# Step1Preheat oven to 350°F (180°C). Line 2 baking sheets with parchment paper.
# Step2In a small bowl, whisk together the flour, baking powder, and salt. Set aside.
# Step3In the bowl of an electric mixer, whip the eggs for a couple of minutes. Add the sugar and vanilla and beat on high speed for 15 minutes until it has thickened.
# Step4While the eggs are whipping, put a medium-to-large saucepan filled with water 3/4 of the way up over medium heat. Place the butter, bittersweet chocolate, and unsweetened chocolate in a medium bowl (not the mini chocolate chips) and place on top of the pot. Adjust the heat so it’s hot but not boiling and stir from time to time until everything is melted and smooth.
# Step5Gently fold the chocolate mixture into the egg mixture using a spatula until partially combined (you should still see some streaks). Add the dry mixture to the batter and carefully fold it in. Add 1 1/2 tablespoons of the chipotle paste (see recipe below in note) and fold in the chocolate chips. If the batter seems very runny, let it rest until it thickens slightly, about 5 to 10 minutes.
# Step6Fill a small bowl with the granulated sugar in one bowl and a separate bowl with the confectioner’s sugar. Drop the batter by heaping teaspoonfuls onto the one with the granulated sugar and roll so it has a nice coating. Then, put into the second bowl filled with the confectioner's sugar and put on the prepared baking sheets, making sure you have about 3 inches (7.5cm) separation between them. Bake until puffed and cracked, 8 to 10 minutes. Cool on a wire rack before removing from the baking sheets.
# Step7NOTE: To make the chipotle paste, toast chiles in a dry heavy skillet over moderate heat, turning, until fragrant, 1 to 2 minutes. Discard stems, seeds, and ribs, then soak chiles in hot water to cover until softened, about 30 minutes. Drain, reserving soaking liquid. Purée chiles in a mini food processor or a blender, adding 2 to 3 tablespoons soaking liquid as needed to form a paste. Force paste through a fine-mesh sieve into a bowl and discard solids. Set aside 1 1/2 tablespoons chile paste and freeze remainder for another use.
# 1Neil's Penicillin
# 2Antibiotic Mocktail
# 3Russ & Daughters' Blintzes
# Company
# About Us
# DEI Vision
# Press
# Jobs
# Affiliate Program
# Get Help
# Contact & FAQ
# Gift Cards
# Advertising Inquiries
# Social
# Facebook
# Instagram
# Pinterest
# TikTok
# YouTube
#
#
#
#
#
# Privacy Policy
# Terms & Conditions
# Code of Conduct
# Accessibility Policy

# %% [markdown]
# # getting all ingredients from one URL

# %%
import re

first_link= "https://food52.com/recipes/82256-chipotle-chocolate-crinkle-cookies"
response= requests.get(first_link)
html_content= response.text
pattern= re.compile(r'"recipeIngredient":\s*\[([^\]]+)\]', re.DOTALL)
match= pattern.search(html_content)
matches= pattern.findall(html_content)

ingredients_list = []
if match:
  raw_ingredients= match.group(1)
  ingredients_list = re.findall(r'"([^"]+)"', raw_ingredients)

print(json.dumps(ingredients_list, indent=2))
# Out:
# [
#   "1/4 cup (31g) all-purpose flour",
#   "1/4 teaspoon baking powder",
#   "1/4 teaspoon salt",
#   "2  large eggs",
#   "2/3 cup (133g) granulated sugar",
#   "1 1/4 teaspoon pure Mexican vanilla extract",
#   "2 tablespoon unsalted butter",
#   "5 ounce (142g) extra-bittersweet chocolate, chopped",
#   "2 ounce (57g) unsweetened chocolate, chopped",
#   "4 ounce (113g) mini chocolate chips or bittersweet chocolate, finely chopped",
#   "1 1/2 tablespoon chipotle chile paste (recipe below)",
#   "6  medium chipotle chiles (for chipotle paste\u2014see note) (1 ounce, or 28g)",
#   "Granulated sugar",
#   "Confectioner's sugar"
# ]

# %% [markdown]
# # format ingredients from one URL into json format
#
# ### ---- inspection line by line ----

# %%
line = ingredients_list[0]
print(line)

## we want to extract the amount unit and ingredient from this
## the ingredient is all-purpose flour
## the amount is 1/4
## unit is cup

pattern = re.compile(
    r'^(?P<amount>(?:\d+\s)?\d+/\d+|\d+)\s+'
    r'(?P<unit>\w+)\s*'
    r'(?:\([^\)]+\)\s*)?'
    r'(?P<ingredient>.+)$'
)


match = pattern.match(line)

if match:
    amount= match.group("amount")
    unit= match.group("unit")
    ingredient = match.group("ingredient")

    print({
        "amount": amount,
        "unit": unit,
        "ingredient": ingredient
    })
# Out:
# 1/4 cup (31g) all-purpose flour
# {'amount': '1/4', 'unit': 'cup', 'ingredient': 'all-purpose flour'}

# %% [markdown]
# ### -- loop through all lines --

# %%
ingredients_parsed = []
for line in ingredients_list:
    match= pattern.match(line)
    if match:
        amount = match.group("amount").strip()
        unit = match.group("unit").strip()
        ingredient = match.group("ingredient").strip()
        ingredients_parsed.append({
            "amount": amount,
            "unit": unit,
            "ingredient": ingredient
        })
    else:
        ingredients_parsed.append({
            "amount": "",
            "unit": "",
            "ingredient": line.strip()
        })

recipe_json = {
    "recipes": [
        {
            "name": "chipotle chocolate crinkle cookies",
            "ingredients": ingredients_parsed
        }
    ]
}

print(json.dumps(recipe_json, indent=2))
# Out:
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "2/3",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1 1/4",
#           "unit": "teaspoon",
#           "ingredient": "pure Mexican vanilla extract"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "unsalted butter"
#         },
#         {
#           "amount": "5",
#           "unit": "ounce",
#           "ingredient": "extra-bittersweet chocolate, chopped"
#         },
#         {
#           "amount": "2",
#           "unit": "ounce",
#           "ingredient": "unsweetened chocolate, chopped"
#         },
#         {
#           "amount": "4",
#           "unit": "ounce",
#           "ingredient": "mini chocolate chips or bittersweet chocolate, finely chopped"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "tablespoon",
#           "ingredient": "chipotle chile paste (recipe below)"
#         },
#         {
#           "amount": "6",
#           "unit": "medium",
#           "ingredient": "chipotle chiles (for chipotle paste\u2014see note) (1 ounce, or 28g)"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Granulated sugar"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Confectioner's sugar"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## -- get unique ingredients from each site --

# %%
unique_ingredients = []
seen_ingredients= set()

for ing in recipe_json["recipes"][0]["ingredients"]:
    key = ing["ingredient"].lower().strip()
    if key not in seen_ingredients:
        unique_ingredients.append(ing)
        seen_ingredients.add(key)

recipe_json["recipes"][0]["ingredients"] = unique_ingredients

import json
print(json.dumps(recipe_json, indent=2))
# Out:
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "2/3",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1 1/4",
#           "unit": "teaspoon",
#           "ingredient": "pure Mexican vanilla extract"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "unsalted butter"
#         },
#         {
#           "amount": "5",
#           "unit": "ounce",
#           "ingredient": "extra-bittersweet chocolate, chopped"
#         },
#         {
#           "amount": "2",
#           "unit": "ounce",
#           "ingredient": "unsweetened chocolate, chopped"
#         },
#         {
#           "amount": "4",
#           "unit": "ounce",
#           "ingredient": "mini chocolate chips or bittersweet chocolate, finely chopped"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "tablespoon",
#           "ingredient": "chipotle chile paste (recipe below)"
#         },
#         {
#           "amount": "6",
#           "unit": "medium",
#           "ingredient": "chipotle chiles (for chipotle paste\u2014see note) (1 ounce, or 28g)"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Confectioner's sugar"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## -- will do this for all 62 recipes I have --
#
# ## create a function for each part

# %%
url2 = filtered_urls[1]
print(url2)

import re

def ingredients_from_url(url):
  response = requests.get(url)
  html_content = response.text
  pattern = re.compile(r'"recipeIngredient":\s*\[([^\]]+)\]', re.DOTALL)
  match=pattern.search(html_content)
  matches= pattern.findall(html_content)
  ingredients_list = []
  if match:
    raw_ingredients = match.group(1)
    ingredients_list = re.findall(r'"([^"]+)"', raw_ingredients)
  print(json.dumps(ingredients_list, indent=2))
  return ingredients_list


def format_ingredients_all_lines(ingredients_list):
  ingredients_parsed = []
  for line in ingredients_list:
      match = pattern.match(line)
      if match:
          amount = match.group("amount").strip()
          unit = match.group("unit").strip()
          ingredient = match.group("ingredient").strip()
          ingredients_parsed.append({
              "amount": amount,
              "unit": unit,
              "ingredient": ingredient
          })
      else:
          ingredients_parsed.append({
              "amount": "",
              "unit": "",
              "ingredient": line.strip()
          })

  recipe_json = {
      "recipes": [
          {
              "name": "chipotle chocolate crinkle cookies",
              "ingredients": ingredients_parsed
          }
      ]
  }

  print(json.dumps(recipe_json, indent=2))
  return recipe_json



def unique_ingredients(recipe_json):
  unique_ingredients = []
  seen_ingredients= set()

  for ing in recipe_json["recipes"][0]["ingredients"]:
      key = ing["ingredient"].lower().strip()
      if key not in seen_ingredients:
          unique_ingredients.append(ing)
          seen_ingredients.add(key)

  recipe_json["recipes"][0]["ingredients"] = unique_ingredients
  print(json.dumps(recipe_json, indent=2))
  return recipe_json


url2 = filtered_urls[1]
print("--Here begins the running of function ingredients from url--")
ingredients_list_new = ingredients_from_url(url2)
print("--All the ingredients of one url are captured--")
print("\n")
print("\n")

print("--Here begins the running of function formatting ingredients all lines--")
recipe_json = format_ingredients_all_lines(ingredients_list_new)
print("--all the ingredients of one url are captured into json format--")
print("\n")
print("\n")

print("--Here begins the running of function unique ingredients--")
recipe_json_unique = unique_ingredients(recipe_json)
recipe_json_unique
print("--Here ends the running of function unique ingredients--")
print("\n")
print("\n")
# Out:
# https://food52.com/recipes/82219-chai-spice-snickerdoodle-recipe
# --Here begins the running of function ingredients from url--
# [
#   "1/4 cup (50g) granulated sugar",
#   "1/2 teaspoon ginger powder, ground",
#   "1 1/2 teaspoon cardamom, freshly ground",
#   "1/2 teaspoon cinnamon, freshly ground",
#   "1 pinch cloves, freshly ground",
#   "1/2 cup (118ml) canola oil",
#   "1 cup (200g) granulated sugar",
#   "1/4 cup (59ml) pure maple syrup",
#   "3 tablespoon whole milk",
#   "2 teaspoon pure vanilla extract",
#   "2 cup (250g) flour",
#   "1 teaspoon baking soda",
#   "1/4 teaspoon salt",
#   "1/2 teaspoon cinnamon, ground"
# ]
# --All the ingredients of one url are captured--
#
#
#
#
# --Here begins the running of function formatting ingredients all lines--
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "ginger powder, ground"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "teaspoon",
#           "ingredient": "cardamom, freshly ground"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "cinnamon, freshly ground"
#         },
#         {
#           "amount": "1",
#           "unit": "pinch",
#           "ingredient": "cloves, freshly ground"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "canola oil"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "pure maple syrup"
#         },
#         {
#           "amount": "3",
#           "unit": "tablespoon",
#           "ingredient": "whole milk"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "pure vanilla extract"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "cinnamon, ground"
#         }
#       ]
#     }
#   ]
# }
# --all the ingredients of one url are captured into json format--
#
#
#
#
# --Here begins the running of function unique ingredients--
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "ginger powder, ground"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "teaspoon",
#           "ingredient": "cardamom, freshly ground"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "cinnamon, freshly ground"
#         },
#         {
#           "amount": "1",
#           "unit": "pinch",
#           "ingredient": "cloves, freshly ground"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "canola oil"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "pure maple syrup"
#         },
#         {
#           "amount": "3",
#           "unit": "tablespoon",
#           "ingredient": "whole milk"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "pure vanilla extract"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "cinnamon, ground"
#         }
#       ]
#     }
#   ]
# }
# --Here ends the running of function unique ingredients--

# %%
sixty_two_recipes_json = {"recipes": []}

for idx, url in enumerate(filtered_urls):
    print(f"Processing {idx+1}/{len(filtered_urls)}: {url}")

    ingredients_list_new = ingredients_from_url(url)

    recipe_json = format_ingredients_all_lines(ingredients_list_new)

    recipe_json_unique = unique_ingredients(recipe_json)

    recipe_name = url.split("/")[-1].split("-", 1)[-1].replace("-", " ")
    recipe_json_unique["recipes"][0]["name"] = recipe_name

    sixty_two_recipes_json["recipes"].append(recipe_json_unique["recipes"][0])
    print(f"Finished: {recipe_name}\n")

import json
with open("62_cookies_recipes.json", "w") as f:
    json.dump(sixty_two_recipes_json, f, indent=2)

print(f"Total recipes saved: {len(sixty_two_recipes_json['recipes'])}")
# Out:
# Streaming output truncated to the last 5000 lines.
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "whipping cream"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "250",
#           "unit": "gram",
#           "ingredient": "finely chopped dark chocolate"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "all-purpose flour, plus more for rolling"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "unsweetened shredded coconut"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "water"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "whipping cream"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "250",
#           "unit": "gram",
#           "ingredient": "finely chopped dark chocolate"
#         }
#       ]
#     }
#   ]
# }
# Finished: homemade samoa inspired cookies
#
# Processing 26/62: https://food52.com/recipes/25558-chocolate-chip-cookies
# [
#   "2 1/8 cup all-purpose flour",
#   "1 teaspoon baking soda",
#   "1 teaspoon kosher salt",
#   "1 1/2 cup regular semisweet chocolate chips",
#   "1 cup large bittersweet chocolate chips",
#   "1 1/2 cup walnuts, finely chopped",
#   "1 cup (2 sticks) unsalted butter, room temperature",
#   "1  cup light or dark brown sugar, tightly packed",
#   "1/2 cup white sugar",
#   "2  eggs",
#   "2  teaspoon vanilla extract"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "2 1/8",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "regular semisweet chocolate chips"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "large bittersweet chocolate chips"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "walnuts, finely chopped"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "light or dark brown sugar, tightly packed"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "white sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "egg",
#           "ingredient": "s"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "2 1/8",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "regular semisweet chocolate chips"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "large bittersweet chocolate chips"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "walnuts, finely chopped"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "light or dark brown sugar, tightly packed"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "white sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "egg",
#           "ingredient": "s"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         }
#       ]
#     }
#   ]
# }
# Finished: chocolate chip cookies
#
# Processing 27/62: https://food52.com/recipes/55184-oatmeal-raisin-cookies
# [
#   "1/2 cup plus 6 tablespoons butter, softened",
#   "3/4 cup firmly packed brown sugar",
#   "1/2 cup granulated sugar",
#   "2  eggs",
#   "1 teaspoon vanilla extract",
#   "1 1/2 cup all-purpose flour",
#   "1 teaspoon baking soda",
#   "1/4 teaspoon ground nutmeg",
#   "1/2 teaspoon salt",
#   "3 cup rolled oats",
#   "1 cup raisins"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "plus 6 tablespoons butter, softened"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "firmly packed brown sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "egg",
#           "ingredient": "s"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "ground nutmeg"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "3",
#           "unit": "cup",
#           "ingredient": "rolled oats"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "raisins"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "plus 6 tablespoons butter, softened"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "firmly packed brown sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "egg",
#           "ingredient": "s"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "ground nutmeg"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "3",
#           "unit": "cup",
#           "ingredient": "rolled oats"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "raisins"
#         }
#       ]
#     }
#   ]
# }
# Finished: oatmeal raisin cookies
#
# Processing 28/62: https://food52.com/blog/26755-dorie-greenspan-chocolate-chip-cookies
# []
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": []
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": []
#     }
#   ]
# }
# Finished: dorie greenspan chocolate chip cookies
#
# Processing 29/62: https://food52.com/recipes/85345-matcha-mochi-cookies
# [
#   "3/4 cup (170 grams) unsalted butter, at room temperature",
#   "3/4 cup (151 grams) granulated sugar",
#   "2 tablespoon (27.5 grams) light brown sugar, packed",
#   "2 cup plus 2 tablespoons (272 grams) all-purpose flour",
#   "1/2 teaspoon baking powder",
#   "1 teaspoon baking soda",
#   "2 1/2 tablespoon matcha powder",
#   "1/2 teaspoon kosher salt",
#   "2  large eggs",
#   "1 1/2 teaspoon vanilla extract",
#   "1/2 cup (80 grams) Mochiko sweet glutinous rice flour",
#   "2 tablespoon (20 grams) cornstarch",
#   "3 tablespoon (40 grams) granulated sugar",
#   "1/2  (130 grams) whole milk",
#   "1/4 teaspoon kosher salt",
#   "1/3 cup (113 grams) raspberry preserves",
#   "1 tablespoon unsalted butter",
#   "1/4 cup (54 grams) canola oil"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "unsalted butter, at room temperature"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "light brown sugar, packed"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "plus 2 tablespoons (272 grams) all-purpose flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "2 1/2",
#           "unit": "tablespoon",
#           "ingredient": "matcha powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "Mochiko sweet glutinous rice flour"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "cornstarch"
#         },
#         {
#           "amount": "3",
#           "unit": "tablespoon",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1/2  (130 grams) whole milk"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "raspberry preserves"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "unsalted butter"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "canola oil"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "unsalted butter, at room temperature"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "light brown sugar, packed"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "plus 2 tablespoons (272 grams) all-purpose flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "2 1/2",
#           "unit": "tablespoon",
#           "ingredient": "matcha powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "Mochiko sweet glutinous rice flour"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "cornstarch"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1/2  (130 grams) whole milk"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "raspberry preserves"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "unsalted butter"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "canola oil"
#         }
#       ]
#     }
#   ]
# }
# Finished: matcha mochi cookies
#
# Processing 30/62: https://food52.com/recipes/83762-aunt-lollys-oatmeal-chocolate-chip-cookie-recipe
# [
#   "1/4 pound butter (one stick), at room temperature",
#   "1/2 cup granulated sugar",
#   "1/2 cup brown sugar",
#   "1  egg",
#   "3/4 cup flour",
#   "1/2 teaspoon baking soda",
#   "1/2 teaspoon kosher salt",
#   "1/2 teaspoon vanilla extract",
#   "1/2 cup rolled oats",
#   "1/2 cup chocolate chips"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/4",
#           "unit": "pound",
#           "ingredient": "butter (one stick), at room temperature"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "brown sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "eg",
#           "ingredient": "g"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "rolled oats"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "chocolate chips"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/4",
#           "unit": "pound",
#           "ingredient": "butter (one stick), at room temperature"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "brown sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "eg",
#           "ingredient": "g"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "rolled oats"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "chocolate chips"
#         }
#       ]
#     }
#   ]
# }
# Finished: aunt lollys oatmeal chocolate chip cookie recipe
#
# Processing 31/62: https://food52.com/recipes/85072-3-ingredient-peanut-butter-cookies-recipe
# [
#   "1  (16-ounce) jar unsweetened peanut butter",
#   "1  (13-ounce) jar apricot or peach jam",
#   "2  large eggs",
#   "Flaky salt (optional)"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1  (16-ounce) jar unsweetened peanut butter"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1  (13-ounce) jar apricot or peach jam"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Flaky salt (optional)"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1  (16-ounce) jar unsweetened peanut butter"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1  (13-ounce) jar apricot or peach jam"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Flaky salt (optional)"
#         }
#       ]
#     }
#   ]
# }
# Finished: 3 ingredient peanut butter cookies recipe
#
# Processing 32/62: https://food52.com/recipes/82252-strawberry-white-chocolate-macadamia-nut-milk-chocolate-cookie-recipe
# [
#   "2 cup (180g) oat flour",
#   "1/4 teaspoon baking soda",
#   "1/4  teaspoon kosher salt",
#   "1/2 cup (1 stick, 1/4 pound, or 113g) unsalted butter, room temperature",
#   "1/2 cup (100g) granulated sugar",
#   "1/2 cup (100g) packed light brown sugar",
#   "1 teaspoon vanilla extract",
#   "1  large egg",
#   "1 1/2 cup (30g) dehydrated strawberries, crushed into bite-sized pieces",
#   "3 ounce (85g) white chocolate, chopped",
#   "1/3 cup (50g) toasted macadamia nuts, roughly chopped",
#   "1 1/2  cup (135g) oat flour",
#   "1/2 cup (50g) Dutch processed cocoa powder",
#   "2 tablespoon (10g) milk powder",
#   "1 tablespoon (5g) instant coffee or espresso powder",
#   "1/4 teaspoon baking soda",
#   "1/4 teaspoon kosher salt",
#   "1/2 cup (1 stick, 1/4 pound, or 113g) unsalted butter, room temperature",
#   "1/2 cup (100g) granulated sugar",
#   "1/2 cup (100g) packed light brown sugar",
#   "1 teaspoon vanilla extract",
#   "1  large egg, room temperature",
#   "12  chocolate wafer sandwich cookies, filling removed and crushed into 1/2-inch/1.2-cm pieces (gluten-free, if desired)",
#   "1/2 cup (60g) mini pretzels, crushed into 1/2-inch pieces (gluten-free if desired), optional"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "oat flour"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "packed light brown sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "dehydrated strawberries, crushed into bite-sized pieces"
#         },
#         {
#           "amount": "3",
#           "unit": "ounce",
#           "ingredient": "white chocolate, chopped"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "toasted macadamia nuts, roughly chopped"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "oat flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "Dutch processed cocoa powder"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "milk powder"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "instant coffee or espresso powder"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "packed light brown sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg, room temperature"
#         },
#         {
#           "amount": "12",
#           "unit": "chocolate",
#           "ingredient": "wafer sandwich cookies, filling removed and crushed into 1/2-inch/1.2-cm pieces (gluten-free, if desired)"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "mini pretzels, crushed into 1/2-inch pieces (gluten-free if desired), optional"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "oat flour"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "packed light brown sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "dehydrated strawberries, crushed into bite-sized pieces"
#         },
#         {
#           "amount": "3",
#           "unit": "ounce",
#           "ingredient": "white chocolate, chopped"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "toasted macadamia nuts, roughly chopped"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "Dutch processed cocoa powder"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "milk powder"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "instant coffee or espresso powder"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg, room temperature"
#         },
#         {
#           "amount": "12",
#           "unit": "chocolate",
#           "ingredient": "wafer sandwich cookies, filling removed and crushed into 1/2-inch/1.2-cm pieces (gluten-free, if desired)"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "mini pretzels, crushed into 1/2-inch pieces (gluten-free if desired), optional"
#         }
#       ]
#     }
#   ]
# }
# Finished: strawberry white chocolate macadamia nut milk chocolate cookie recipe
#
# Processing 33/62: https://food52.com/recipes/82215-salted-rosemary-shortbread
# [
#   "1 1/2 cup (180g) unbleached all-purpose flour",
#   "1/3 cup (43g) rice flour",
#   "1/2 teaspoon kosher salt, plus more to taste",
#   "2 tablespoon fresh rosemary, finely chopped",
#   "1 cup (2 sticks, 1/2 pound, or 227g) unsalted butter, room temperature",
#   "1/2 cup plus 1 tablespoon (112g) granulated sugar, divided",
#   "2 teaspoon finely grated grapefruit zest",
#   "Flaky sea salt, for topping"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "unbleached all-purpose flour"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "rice flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt, plus more to taste"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "fresh rosemary, finely chopped"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "plus 1 tablespoon (112g) granulated sugar, divided"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "finely grated grapefruit zest"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Flaky sea salt, for topping"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "unbleached all-purpose flour"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "rice flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt, plus more to taste"
#         },
#         {
#           "amount": "2",
#           "unit": "tablespoon",
#           "ingredient": "fresh rosemary, finely chopped"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, room temperature"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "plus 1 tablespoon (112g) granulated sugar, divided"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "finely grated grapefruit zest"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Flaky sea salt, for topping"
#         }
#       ]
#     }
#   ]
# }
# Finished: salted rosemary shortbread
#
# Processing 34/62: https://food52.com/recipes/82667-spiced-pecan-sandies-recipe
# [
#   "150 gram (1 cup plus 3 tablespoons) all-purpose flour",
#   "125 gram (1 stick plus 1 tablespoon) unsalted butter, at room temperature",
#   "90 gram (1/4 cup plus 3 tablespoons and 1 teaspoon) granulated sugar",
#   "90 gram (scant 1 cup) toasted, ground pecans (see Author Notes)",
#   "25 gram (1 1/2) egg yolks",
#   "5 gram (1 teaspoon) masala (see Author Notes)",
#   "3 gram (1/2 teaspoon) kosher salt",
#   "1/4  vanilla bean, scraped"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "150",
#           "unit": "gram",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "125",
#           "unit": "gram",
#           "ingredient": "unsalted butter, at room temperature"
#         },
#         {
#           "amount": "90",
#           "unit": "gram",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "90",
#           "unit": "gram",
#           "ingredient": "toasted, ground pecans (see Author Notes)"
#         },
#         {
#           "amount": "25",
#           "unit": "gram",
#           "ingredient": "egg yolks"
#         },
#         {
#           "amount": "5",
#           "unit": "gram",
#           "ingredient": "masala (see Author Notes)"
#         },
#         {
#           "amount": "3",
#           "unit": "gram",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/4",
#           "unit": "vanilla",
#           "ingredient": "bean, scraped"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "150",
#           "unit": "gram",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "125",
#           "unit": "gram",
#           "ingredient": "unsalted butter, at room temperature"
#         },
#         {
#           "amount": "90",
#           "unit": "gram",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "90",
#           "unit": "gram",
#           "ingredient": "toasted, ground pecans (see Author Notes)"
#         },
#         {
#           "amount": "25",
#           "unit": "gram",
#           "ingredient": "egg yolks"
#         },
#         {
#           "amount": "5",
#           "unit": "gram",
#           "ingredient": "masala (see Author Notes)"
#         },
#         {
#           "amount": "3",
#           "unit": "gram",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/4",
#           "unit": "vanilla",
#           "ingredient": "bean, scraped"
#         }
#       ]
#     }
#   ]
# }
# Finished: spiced pecan sandies recipe
#
# Processing 35/62: https://food52.com/recipes/78310-rose-levy-beranbaum-s-molasses-sugar-butter-cookies
# [
#   "150 gram or 10 1/2 tablespoons (1 stick plus 2 1/2 tablespoons) unsalted butter",
#   "38 gram or 2 tablespoons plus 1 teaspoon (35 ml) or 3/4 large egg",
#   "204 gram or 1 3/4 cups minus 1 tablespoon (lightly spooned into the cup and leveled off) bleached all-purpose flour",
#   "8.2 gram or 1 1/2 teaspoons baking soda",
#   "3/8 teaspoon fine sea salt",
#   "3/4 teaspoon ground cinnamon",
#   "3/8 teaspoon ground cloves",
#   "3/8 teaspoon ground ginger",
#   "125 gram or 1/2 cup plus 2 tablespoons superfine sugar",
#   "60 gram or 3 tablespoons (45 ml) light molasses, preferably Grandma\u2019s brand",
#   "24 gram or 2 tablespoons superfine sugar, for rolling the dough balls (see Baking Pearls)"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "150",
#           "unit": "gram",
#           "ingredient": "or 10 1/2 tablespoons (1 stick plus 2 1/2 tablespoons) unsalted butter"
#         },
#         {
#           "amount": "38",
#           "unit": "gram",
#           "ingredient": "or 2 tablespoons plus 1 teaspoon (35 ml) or 3/4 large egg"
#         },
#         {
#           "amount": "204",
#           "unit": "gram",
#           "ingredient": "or 1 3/4 cups minus 1 tablespoon (lightly spooned into the cup and leveled off) bleached all-purpose flour"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "8.2 gram or 1 1/2 teaspoons baking soda"
#         },
#         {
#           "amount": "3/8",
#           "unit": "teaspoon",
#           "ingredient": "fine sea salt"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "ground cinnamon"
#         },
#         {
#           "amount": "3/8",
#           "unit": "teaspoon",
#           "ingredient": "ground cloves"
#         },
#         {
#           "amount": "3/8",
#           "unit": "teaspoon",
#           "ingredient": "ground ginger"
#         },
#         {
#           "amount": "125",
#           "unit": "gram",
#           "ingredient": "or 1/2 cup plus 2 tablespoons superfine sugar"
#         },
#         {
#           "amount": "60",
#           "unit": "gram",
#           "ingredient": "or 3 tablespoons (45 ml) light molasses, preferably Grandma\u2019s brand"
#         },
#         {
#           "amount": "24",
#           "unit": "gram",
#           "ingredient": "or 2 tablespoons superfine sugar, for rolling the dough balls (see Baking Pearls)"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "150",
#           "unit": "gram",
#           "ingredient": "or 10 1/2 tablespoons (1 stick plus 2 1/2 tablespoons) unsalted butter"
#         },
#         {
#           "amount": "38",
#           "unit": "gram",
#           "ingredient": "or 2 tablespoons plus 1 teaspoon (35 ml) or 3/4 large egg"
#         },
#         {
#           "amount": "204",
#           "unit": "gram",
#           "ingredient": "or 1 3/4 cups minus 1 tablespoon (lightly spooned into the cup and leveled off) bleached all-purpose flour"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "8.2 gram or 1 1/2 teaspoons baking soda"
#         },
#         {
#           "amount": "3/8",
#           "unit": "teaspoon",
#           "ingredient": "fine sea salt"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "ground cinnamon"
#         },
#         {
#           "amount": "3/8",
#           "unit": "teaspoon",
#           "ingredient": "ground cloves"
#         },
#         {
#           "amount": "3/8",
#           "unit": "teaspoon",
#           "ingredient": "ground ginger"
#         },
#         {
#           "amount": "125",
#           "unit": "gram",
#           "ingredient": "or 1/2 cup plus 2 tablespoons superfine sugar"
#         },
#         {
#           "amount": "60",
#           "unit": "gram",
#           "ingredient": "or 3 tablespoons (45 ml) light molasses, preferably Grandma\u2019s brand"
#         },
#         {
#           "amount": "24",
#           "unit": "gram",
#           "ingredient": "or 2 tablespoons superfine sugar, for rolling the dough balls (see Baking Pearls)"
#         }
#       ]
#     }
#   ]
# }
# Finished: rose levy beranbaum s molasses sugar butter cookies
#
# Processing 36/62: https://food52.com/recipes/39753-s-mores-cookies
# [
#   "1 cup miniature marshmallows",
#   "1 cup all-purpose flour",
#   "1 cup finely crushed graham cracker crumbs",
#   "1/2 cup cocoa powder (I like dark or black cocoa powder for these)",
#   "1 teaspoon baking powder",
#   "1/2 teaspoon kosher salt",
#   "1/2 cup brown sugar",
#   "1/2 cup granulated sugar",
#   "1/2 cup unsalted butter, softened",
#   "2  large eggs",
#   "1 teaspoon vanilla extract",
#   "1 1/2 cup dark chocolate chunks or chips",
#   "1/2 cup shredded unsweetened coconut"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "miniature marshmallows"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "finely crushed graham cracker crumbs"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "cocoa powder (I like dark or black cocoa powder for these)"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "brown sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, softened"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "dark chocolate chunks or chips"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "shredded unsweetened coconut"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "miniature marshmallows"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "finely crushed graham cracker crumbs"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "cocoa powder (I like dark or black cocoa powder for these)"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "brown sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, softened"
#         },
#         {
#           "amount": "2",
#           "unit": "large",
#           "ingredient": "eggs"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "dark chocolate chunks or chips"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "shredded unsweetened coconut"
#         }
#       ]
#     }
#   ]
# }
# Finished: s mores cookies
#
# Processing 37/62: https://food52.com/recipes/86168-best-applesauce-chocolate-chip-cookies-recipe
# [
#   "3 cup unsweetened applesauce",
#   "1 cup (2 sticks) unsalted butter, divided",
#   "1\u00bd cup all-purpose flour",
#   "1/2 teaspoon baking powder",
#   "1\u00bd teaspoon baking soda",
#   "1\u00bd teaspoon kosher salt",
#   "1/3 cup granulated sugar",
#   "1/3 cup (packed) light brown sugar",
#   "1  large egg, room temperature",
#   "2 teaspoon vanilla paste or extract",
#   "1\u00bd cup (heaping) bitter- or semisweet chocolate chips or chunks (I used 64% cacao), plus more for sprinkling",
#   "Coarse salt, for finishing"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "3",
#           "unit": "cup",
#           "ingredient": "unsweetened applesauce"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, divided"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd cup all-purpose flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd teaspoon baking soda"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd teaspoon kosher salt"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "light brown sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg, room temperature"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla paste or extract"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd cup (heaping) bitter- or semisweet chocolate chips or chunks (I used 64% cacao), plus more for sprinkling"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Coarse salt, for finishing"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "3",
#           "unit": "cup",
#           "ingredient": "unsweetened applesauce"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, divided"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd cup all-purpose flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd teaspoon baking soda"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd teaspoon kosher salt"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1/3",
#           "unit": "cup",
#           "ingredient": "light brown sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg, room temperature"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla paste or extract"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "1\u00bd cup (heaping) bitter- or semisweet chocolate chips or chunks (I used 64% cacao), plus more for sprinkling"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "Coarse salt, for finishing"
#         }
#       ]
#     }
#   ]
# }
# Finished: best applesauce chocolate chip cookies recipe
#
# Processing 38/62: https://food52.com/recipes/84404-best-butter-cookies-recipe-with-fruit
# [
#   "1 cup (2 sticks) unsalted butter, at room temperature",
#   "3/4 cup granulated sugar",
#   "3  large egg yolks",
#   "1 teaspoon freshly grated orange zest",
#   "2 1/2 cup all-purpose flour",
#   "1/2 teaspoon baking powder",
#   "1/2 teaspoon kosher salt",
#   "1/2 cup pistachios, roughly chopped",
#   "1/2 cup dried apricots, roughly chopped",
#   "1/2 cup dried sour cherries, roughly chopped",
#   "4 ounce bittersweet chocolate, melted",
#   "1 teaspoon neutral oil, such as coconut or vegetable"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, at room temperature"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "3",
#           "unit": "large",
#           "ingredient": "egg yolks"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "freshly grated orange zest"
#         },
#         {
#           "amount": "2 1/2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "pistachios, roughly chopped"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "dried apricots, roughly chopped"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "dried sour cherries, roughly chopped"
#         },
#         {
#           "amount": "4",
#           "unit": "ounce",
#           "ingredient": "bittersweet chocolate, melted"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "neutral oil, such as coconut or vegetable"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "unsalted butter, at room temperature"
#         },
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "3",
#           "unit": "large",
#           "ingredient": "egg yolks"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "freshly grated orange zest"
#         },
#         {
#           "amount": "2 1/2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "pistachios, roughly chopped"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "dried apricots, roughly chopped"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "dried sour cherries, roughly chopped"
#         },
#         {
#           "amount": "4",
#           "unit": "ounce",
#           "ingredient": "bittersweet chocolate, melted"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "neutral oil, such as coconut or vegetable"
#         }
#       ]
#     }
#   ]
# }
# Finished: best butter cookies recipe with fruit
#
# Processing 39/62: https://food52.com/recipes/78230-vegan-dark-chocolate-gingerbread-thumbprint-cookies
# [
#   "1 cup coconut sugar, plus 3 tablespoons",
#   "2 cup water",
#   "1  3\u2013inch piece of ginger, peeled and sliced into coins about 1/8-inch thick",
#   "1 1/2 cup oat flour (store-bought works best) (180 grams)",
#   "1/2 cup (68 grams) super-fine almond flour",
#   "1/2 cup (72 grams) coconut sugar",
#   "1 teaspoon (4 grams) baking powder",
#   "2 teaspoon (6 grams) ground cinnamon",
#   "1 tablespoon (7 grams) ground ginger",
#   "1/4 teaspoon (1 gram) ground nutmeg",
# ...
#   "4 ounce cream cheese, at room temperature",
#   "2 cup powdered sugar",
#   "1 tablespoon heavy cream",
#   "1 teaspoon vanilla extract",
#   "1/4  teaspoon salt",
#   "sprinkles, for decorating"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "butter, at room temperature"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "sugar"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "light brown sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "egg",
#           "ingredient": "s"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla bean paste (or vanilla extract)"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "butter, at room temperature"
#         },
#         {
#           "amount": "4",
#           "unit": "ounce",
#           "ingredient": "cream cheese, at room temperature"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "powdered sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "heavy cream"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "sprinkles, for decorating"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "3/4",
#           "unit": "cup",
#           "ingredient": "butter, at room temperature"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "sugar"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "light brown sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "egg",
#           "ingredient": "s"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla bean paste (or vanilla extract)"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "flour"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "4",
#           "unit": "ounce",
#           "ingredient": "cream cheese, at room temperature"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "powdered sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "heavy cream"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "",
#           "unit": "",
#           "ingredient": "sprinkles, for decorating"
#         }
#       ]
#     }
#   ]
# }
# Finished: sugar cookie bars
#
# Processing 59/62: https://food52.com/recipes/84523-best-gingerbread-cookies-recipe
# [
#   "1 1/3 cup (302 grams) unsalted butter",
#   "4 teaspoon ground ginger",
#   "3/4 teaspoon ground cloves (preferably freshly ground)",
#   "3 1/2 cup (420 grams) all-purpose flour, plus 1/4 cup (30 grams) as needed",
#   "1 teaspoon baking soda",
#   "3/4 teaspoon kosher salt (Diamond Crystal)",
#   "1/2 cup (107 grams) light brown sugar",
#   "1/2 cup (170 grams) molasses",
#   "1  large egg"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1 1/3",
#           "unit": "cup",
#           "ingredient": "unsalted butter"
#         },
#         {
#           "amount": "4",
#           "unit": "teaspoon",
#           "ingredient": "ground ginger"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "ground cloves (preferably freshly ground)"
#         },
#         {
#           "amount": "3 1/2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour, plus 1/4 cup (30 grams) as needed"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt (Diamond Crystal)"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "light brown sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "molasses"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1 1/3",
#           "unit": "cup",
#           "ingredient": "unsalted butter"
#         },
#         {
#           "amount": "4",
#           "unit": "teaspoon",
#           "ingredient": "ground ginger"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "ground cloves (preferably freshly ground)"
#         },
#         {
#           "amount": "3 1/2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour, plus 1/4 cup (30 grams) as needed"
#         },
#         {
#           "amount": "1",
#           "unit": "teaspoon",
#           "ingredient": "baking soda"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "kosher salt (Diamond Crystal)"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "light brown sugar"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "molasses"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg"
#         }
#       ]
#     }
#   ]
# }
# Finished: best gingerbread cookies recipe
#
# Processing 60/62: https://food52.com/recipes/67298-russian-tea-cakes
# [
#   "1 1/2 cup 1 1/2 cups nuts (210 grams almond or hazelnuts, 150 grams pecans or walnuts, 170 grams peanuts, 190 grams macadamias, 255 grams pistachios)",
#   "1/4 cup (50 grams) granulated sugar",
#   "2 cup (255 grams) unbleached all-purpose flour",
#   "3/4 teaspoon salt",
#   "16 tablespoon (225 grams or 2 sticks) unsalted butter, softened and cut into small chunks",
#   "2 teaspoon vanilla extract",
#   "1  egg yolk (optional)",
#   "1/2 cup powdered sugar"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "1 1/2 cups nuts (210 grams almond or hazelnuts, 150 grams pecans or walnuts, 170 grams peanuts, 190 grams macadamias, 255 grams pistachios)"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "unbleached all-purpose flour"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "16",
#           "unit": "tablespoon",
#           "ingredient": "unsalted butter, softened and cut into small chunks"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1",
#           "unit": "egg",
#           "ingredient": "yolk (optional)"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "powdered sugar"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1 1/2",
#           "unit": "cup",
#           "ingredient": "1 1/2 cups nuts (210 grams almond or hazelnuts, 150 grams pecans or walnuts, 170 grams peanuts, 190 grams macadamias, 255 grams pistachios)"
#         },
#         {
#           "amount": "1/4",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "unbleached all-purpose flour"
#         },
#         {
#           "amount": "3/4",
#           "unit": "teaspoon",
#           "ingredient": "salt"
#         },
#         {
#           "amount": "16",
#           "unit": "tablespoon",
#           "ingredient": "unsalted butter, softened and cut into small chunks"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1",
#           "unit": "egg",
#           "ingredient": "yolk (optional)"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "powdered sugar"
#         }
#       ]
#     }
#   ]
# }
# Finished: russian tea cakes
#
# Processing 61/62: https://food52.com/recipes/82253-sugar-cookies-with-vanilla-frosting
# [
#   "1/2 cup (1 stick, 1/4 pound, or 113g) unsalted butter, softened",
#   "1 cup (200g) granulated sugar",
#   "1  large egg",
#   "1/2 teaspoon vanilla extract",
#   "1/2 teaspoon fine sea salt",
#   "2 teaspoon baking powder",
#   "1 to 2 tablespoon cold water",
#   "2 cup (250g) all-purpose flour",
#   "1  batch Vanilla Frosting (recipe below)",
#   "1/2 cup (1 stick, 1/4 pound, or 113g) unsalted butter, softened",
#   "1 pound (455g) powdered sugar, sifted",
#   "3 to 4 tablespoon whole milk",
#   "1  vanilla bean, seeds scraped out (or 1 t vanilla bean paste or vanilla extract)"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, softened"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "fine sea salt"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1",
#           "unit": "to",
#           "ingredient": "2 tablespoon cold water"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "batch",
#           "ingredient": "Vanilla Frosting (recipe below)"
#         },
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, softened"
#         },
#         {
#           "amount": "1",
#           "unit": "pound",
#           "ingredient": "powdered sugar, sifted"
#         },
#         {
#           "amount": "3",
#           "unit": "to",
#           "ingredient": "4 tablespoon whole milk"
#         },
#         {
#           "amount": "1",
#           "unit": "vanilla",
#           "ingredient": "bean, seeds scraped out (or 1 t vanilla bean paste or vanilla extract)"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "1/2",
#           "unit": "cup",
#           "ingredient": "unsalted butter, softened"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "large",
#           "ingredient": "egg"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "1/2",
#           "unit": "teaspoon",
#           "ingredient": "fine sea salt"
#         },
#         {
#           "amount": "2",
#           "unit": "teaspoon",
#           "ingredient": "baking powder"
#         },
#         {
#           "amount": "1",
#           "unit": "to",
#           "ingredient": "2 tablespoon cold water"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         },
#         {
#           "amount": "1",
#           "unit": "batch",
#           "ingredient": "Vanilla Frosting (recipe below)"
#         },
#         {
#           "amount": "1",
#           "unit": "pound",
#           "ingredient": "powdered sugar, sifted"
#         },
#         {
#           "amount": "3",
#           "unit": "to",
#           "ingredient": "4 tablespoon whole milk"
#         },
#         {
#           "amount": "1",
#           "unit": "vanilla",
#           "ingredient": "bean, seeds scraped out (or 1 t vanilla bean paste or vanilla extract)"
#         }
#       ]
#     }
#   ]
# }
# Finished: sugar cookies with vanilla frosting
#
# Processing 62/62: https://food52.com/recipes/86504-my-family-recipe-mom-moms-potato-chip-cookie
# [
#   "2 cup potato chips (preferably Lay\u2019s Classic)",
#   "2  sticks unsalted butter, softened",
#   "1 cup granulated sugar",
#   "1  egg yolk",
#   "1 tablespoon vanilla extract",
#   "2 cup all-purpose flour"
# ]
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "potato chips (preferably Lay\u2019s Classic)"
#         },
#         {
#           "amount": "2",
#           "unit": "sticks",
#           "ingredient": "unsalted butter, softened"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "egg",
#           "ingredient": "yolk"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         }
#       ]
#     }
#   ]
# }
# {
#   "recipes": [
#     {
#       "name": "chipotle chocolate crinkle cookies",
#       "ingredients": [
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "potato chips (preferably Lay\u2019s Classic)"
#         },
#         {
#           "amount": "2",
#           "unit": "sticks",
#           "ingredient": "unsalted butter, softened"
#         },
#         {
#           "amount": "1",
#           "unit": "cup",
#           "ingredient": "granulated sugar"
#         },
#         {
#           "amount": "1",
#           "unit": "egg",
#           "ingredient": "yolk"
#         },
#         {
#           "amount": "1",
#           "unit": "tablespoon",
#           "ingredient": "vanilla extract"
#         },
#         {
#           "amount": "2",
#           "unit": "cup",
#           "ingredient": "all-purpose flour"
#         }
#       ]
#     }
#   ]
# }
# Finished: my family recipe mom moms potato chip cookie
#
# Total recipes saved: 62
